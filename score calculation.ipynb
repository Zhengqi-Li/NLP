# %%
import pandas as pd

# %%
test_labels = pd.read_csv('test_labels.csv')

# %%
real_test = test_labels[test_labels['toxic']>=0]

# %%
from sklearn.metrics import roc_curve,auc,roc_auc_score

# %%
a = [1,0,1,0,1]
b = [1,0,1,0,0]
roc_auc_score(a,b)
# Out:
# 0.8333333333333333

# %%
real_test.columns
# Out:
# Index(['id', 'toxic', 'severe_toxic', 'obscene', 'threat', 'insult',
#        'identity_hate'],
#       dtype='object')

# %%
labels = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult',
       'identity_hate']

# %%
real_test[labels]
# Out:
#         toxic  severe_toxic  obscene  threat  insult  identity_hate
# 5           0             0        0       0       0              0
# 7           0             0        0       0       0              0
# 11          0             0        0       0       0              0
# 13          0             0        0       0       0              0
# 14          0             0        0       0       0              0
# 16          0             0        0       0       0              0
# 17          0             0        0       0       0              0
# 19          0             0        0       0       0              0
# 21          1             0        0       0       0              0
# 22          0             0        0       0       0              0
# 23          0             0        0       0       0              0
# 26          0             0        0       0       0              0
# 28          0             0        0       0       0              0
# ...

# %%
cnn = pd.read_csv('CNN.csv')

# %%
pwd
# Out:
# '/Users/lizhengqi/Downloads/comments'

# %%
cnn.shape
# Out:
# (153164, 7)

# %%
real_test.shape
# Out:
# (63978, 7)

# %%
cnn.iloc[real_test.index].shape
# Out:
# (63978, 7)

# %%
roc_auc_score(real_test[labels], cnn.iloc[real_test.index][labels])
# Out:
# 0.9821760933616143

# %%
gru = pd.read_csv('GRU.csv')

# %%
roc_auc_score(real_test[labels], gru.iloc[real_test.index][labels])
# Out:
# 0.9827124262730207
